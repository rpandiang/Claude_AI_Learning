# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
from os import system


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
 
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages, 
        "temperature": temperature
        }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Suggest me one sentence to describe the importance of learning Python programming language.")

answer = chat(messages, temperature=1.0)

answer
# Out:
# 'Here is one sentence to describe the importance of learning Python programming language:\n\n**"Learning Python is essential in today\'s tech-driven world, as it is a versatile, beginner-friendly, and in-demand programming language used across a wide range of fields, including web development, data science, artificial intelligence, machine learning, and automation, opening up countless career opportunities and enabling you to solve complex real-world problems efficiently."**'

# %%
# Make a starting list of messages
messages = []

# Add in the initial user message
add_user_message(messages, "Define MCP in one sentence.")

# Call the chat function
answer = chat(messages)

# Add the assistant's response to the messages
add_assistant_message(messages, answer)

# Add another user message
add_user_message(messages, "What is the difference between MCP and API?")

# Call the chat function
answer = chat(messages)
messages

# %%
answer

# %%
#Make an initial list of messages
messages = []

# Use a 'while' loop to keep the conversation going until the user types 'exit'
while True:
    user_input = input("> ")
    print(">", user_input)

# Add user input to the messages list
    add_user_message(messages, user_input)
    
# Call Claude with the chat function
    answer = chat(messages)

# Add the assistant's response to the messages list
    add_assistant_message(messages, answer)

# Print the assistant's response
    print("-----")
    print("Claude:", answer)
    print("-----")

# %%
messages = []

system = """You are a patient Math teacher. Do not directly answer the questions. Encourage the student to think critically and guide them through the problem-solving process. Provide hints, ask leading questions, and offer explanations that help the student arrive at the solution on their own. Avoid giving away the answer directly."""

add_user_message(messages, "Solve the equation 2x + 3 = 7.")

answer = chat(messages, system)

answer

# %%
messages = []

add_user_message(messages, "Write a Python function to find the duplicate words in a sentence")

answer = chat(messages, system="You are a Python Engineer who writes concise code.")

answer
